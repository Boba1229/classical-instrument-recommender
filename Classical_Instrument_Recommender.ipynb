# %% [markdown]
# <a href="https://colab.research.google.com/github/Boba1229/classical-instrument-recommender/blob/main/Classical_Instrument_Recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image, display
import os

# Classical instrument and piece data
instruments_data = {
    "violin": {
        "composer": "Pyotr Ilyich Tchaikovsky",
        "piece": "Violin Concerto in D major, Op. 35",
        "image": "violin.jpg"
    },
    "viola": {
        "composer": "William Walton",
        "piece": "Walton Viola Concerto",
        "image": "viola.jpg"
    },
    "cello": {
        "composer": "Franz Joseph Haydn",
        "piece": "Cello Concerto No. 1 in C major, Hob. VIIb/1",
        "image": "cello.jpg"
        },
    "double bass": {
        "composer": "Serge Koussevitzky",
        "piece": "Double Bass Concerto in F-sharp minor, Op. 3",
        "image": "double_bass.jpg"
    },
    "harp": {
        "composer": "George Frideric Handel",
        "piece": "Harp Concerto in B-flat Major, HWV 294, Op. 4, No. 6",
        "image": "harp.jpg"
    },
    "flute": {
        "composer": "Wolfgang Amadeus Mozart",
        "piece": "Flute Concerto No. 1 in G major, K. 313",
        "image": "flute.jpg"
    },
    "piccolo": {
        "composer": "Antonio Vivaldi",
        "piece": "Piccolo Concerto in C Major, RV 443",
        "image": "piccolo.jpg"
    },
    "oboe": {
        "composer": "Wolfgang Amadeus Mozart",
        "piece": "Oboe Concerto in C major, K. 314",
        "image": "oboe.jpg"
    },
    "english horn": {
        "composer": "Joseph Fiala",
        "piece": "Concerto for English Horn and Orchestra in C Major",
        "image": "english_horn.jpg"
    },
    "bass clarinet": {
        "composer": "Geraldine Green",
        "piece": "Bass Clarinet Concerto (for bass clarinet and strings)",
        "image": "bass_clarinet.jpg"
    },
    "bassoon": {
        "composer": "Gioachino Rossini",
        "piece": "Concerto da Esperimento (Examination Concerto)",
        "image": "bassoon.jpg"
    },
    "contrabassoon": {
        "image": "contra_bassoon.jpg"
    },
    "timpani": {
        "composer": "William Kraft",
        "piece": "Timpani Concerto No. 1 (1983)",
        "image": "timpani.jpg"
    },
    "marimba": {
        "composer": "Emmanuel Séjourné",
        "piece": "Concerto for Marimba and String Orchestra (2005)",
        "image": "marimba.jpg"
    },
    "horn": {
        "composer": "Richard Strauss",
        "piece": "Horn Concerto No. 1 in E-flat major, Op. 11",
        "image": "horn.jpg"
    },
    "trombone": {
        "composer": "Ferdinand David",
        "piece": "Concertino for Trombone and Orchestra, Op. 4",
        "image": "trombone.jpg"
    },
    "bass trombone": {
        "composer": "Chris Brubeck",
        "piece": "Concerto for Bass Trombone & Orchestra (2000)",
        "image": "bass_trombone.jpg"
    },
    "snare drum": {
        "image": "snare_drum.jpg"
    },
    "tuba": {
        "composer": "Ralph Vaughan Williams",
        "piece": "Concerto in F Minor for Bass Tuba and Orchestra",
        "image": "tuba.jpg"
    },
    "trumpet": {
        "composer": "Joseph Haydn",
        "piece": "Trumpet Concerto in E-flat major",
        "image": "trumpet.jpg"
    },
    "piano": {
        "composer": "Pyotr Ilyich Tchaikovsky",
        "piece": "Piano Concerto No. 1 in B♭ minor, Op. 23",
        "image": "piano.jpg"
    },
    "celesta": {
        "composer": " Béla Bartók",
        "piece": "Music for Strings, Percussion and Celesta, Sz. 106, BB 114",
        "image": "celesta.jpg"
    },
    "clarinet": {
        "composer": "Wolfgang Amadeus Mozart",
        "piece": "Clarinet Concerto in A major, K.622",
        "image": "clarinet.jpg"
    }
}

# Instrument families
instrument_families = {
    "Strings": ["violin", "viola", "cello", "double bass", "harp"],
    "Woodwinds": ["flute", "piccolo", "oboe", "english horn", "clarinet", "bass clarinet", "bassoon", "contrabassoon"],
    "Brass": ["trumpet", "trombone","bass trombone", "horn", "tuba"],
    "Percussion": ["timpani", "snare drum", "marimba"],
    "Other": ["piano", "celesta"]
}

def main():
    print("🎻 Welcome to the Classical Instrument Recommender! 🎼\n")

    while True:
        knows = input("Do you know your favorite classical instrument? (yes/no): ").strip().lower()

        if knows == "yes":
            print("\nHere are the available instruments:")
            instrument_list = list(instruments_data.keys())
            for i, inst in enumerate(instrument_list, 1):
                print(f"{i}. {inst}")
            choice = input("Please enter the number of your favorite instrument: ").strip()
            if choice.isdigit() and 1 <= int(choice) <= len(instrument_list):
                instrument = instrument_list[int(choice) - 1]
            else:
                print("Invalid choice. Please try again.")
                continue
        else:
            # Step 1: Show instrument families
            family_list = list(instrument_families.keys())
            print("\nChoose a category:")
            for i, family in enumerate(family_list, 1):
                print(f"{i}. {family}")
            family_choice = input("\nEnter the number for your chosen category: ").strip()

            if not family_choice.isdigit() or int(family_choice) not in range(1, len(family_list) + 1):
                print("Invalid category. Please try again.")
                continue

            chosen_family = family_list[int(family_choice) - 1]
            instruments_in_family = instrument_families[chosen_family]

            # Step 2: Show instruments in chosen family
            print(f"\nIn the {chosen_family} category, choose an instrument:")
            for i, inst in enumerate(instruments_in_family, 1):
                print(f"{i}. {inst}")
            inst_choice = input("\nEnter the number of your chosen instrument: ").strip()

            if not inst_choice.isdigit() or int(inst_choice) not in range(1, len(instruments_in_family) + 1):
                print("Invalid instrument. Please try again.")
                continue

            instrument = instruments_in_family[int(inst_choice) - 1]

        print("\n---------------------------------------------")

        if instrument in instruments_data:
            data = instruments_data[instrument]
            print(f"🎵 Recommended Piece: {data.get('piece', 'N/A')}")
            print(f"🎼 Composer: {data.get('composer', 'N/A')}")
            image_path = data.get("image")

            if os.path.exists(image_path):
                display(Image(filename=image_path))
            else:
                print(f"[Image file '{image_path}' not found]")
        else:
            print("Sorry, we don't have information about that instrument yet.")

        print("\n✅ Done! You can now choose to explore another instrument below 👇")
        again = input("Would you like to explore another instrument? (yes/no): ").strip().lower()
        if again != "yes":
            print("\n🎉 Thank you for using the Classical Instrument Recommender!")
            break
if __name__ == "__main__":
    main()
# Out:
# 🎻 Welcome to the Classical Instrument Recommender! 🎼
#
# Do you know your favorite classical instrument? (yes/no): 5
#
# Choose a category:
# 1. Strings
# 2. Woodwinds
# 3. Brass
# 4. Percussion
# 5. Other
#
# Enter the number for your chosen category: 1
#
# In the Strings category, choose an instrument:
# 1. violin
# 2. viola
# 3. cello
# 4. double bass
# 5. harp
#
# Enter the number of your chosen instrument: 5
#
# ---------------------------------------------
# 🎵 Recommended Piece: Harp Concerto in B-flat Major, HWV 294, Op. 4, No. 6
# 🎼 Composer: George Frideric Handel
# ✅ Done! You can now choose to explore another instrument below 👇
# Would you like to explore another instrument? (yes/no): yes
# Do you know your favorite classical instrument? (yes/no): yes
#
# Here are the available instruments:
# 1. violin
# 2. viola
# 3. cello
# 4. double bass
# 5. harp
# 6. flute
# 7. piccolo
# 8. oboe
# 9. english horn
# 10. bass clarinet
# 11. bassoon
# 12. contrabassoon
# 13. timpani
# ...
